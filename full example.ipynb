# %% [markdown]
# # Example Audit Process and Documentation in Python
# zyx client
# <br>4/30/2018

# %% [markdown]
# This workpaper represents the testing of controls around user access for zyx.

# %% [markdown]
# ## Risk
# The user IDs of terminated employees are not removed promptly, which may result in unauthorized access to enterprise information.

# %% [markdown]
# # Control
# HR flags personnel as Terminated ("T") in the user access tables when termination is processed.

# %% [markdown]
# # Procedures performed
# 1. We obtained a user listing as of 4/2/18 (48 hours after terminated employees report)
# 2. Obtained a listing of terminated employees as of 3/31/18
# 3. Compare terminated employees to user list to determine if any are listed as Active

# %% [markdown]
# ### Load User List and Terminated List

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
users_file_path = 'files/users.xlsx'

# %%
users_df = pd.read_excel(users_file_path)

# %%
users_df
# Out:
#      UNIT_ID              USER_NAME     USER_ID          EMAIL_ADDR  \
# 0      11703         KARI ALEXANDER  KALEXANDER  kalexander@zyx.com
# 1      20280           LINDA PARKER     LPARKER     lparker@zyx.com
# 2      30126            DANIEL YORK       DYORK       dyork@zyx.com
# 3      30187          CHARLES ALLEN      CALLEN      callen@zyx.com
# 4      30323           JAMIE MARTIN     JMARTIN     jmartin@zyx.com
# 5      30323           JAMIE MARTIN     JMARTIN     jmartin@zyx.com
# 6      30439          MICHAEL DAVIS      MDAVIS      mdavis@zyx.com
# 7      30508          JIMMY ALVAREZ    JALVAREZ    jalvarez@zyx.com
# 8      30630      MISS NICOLE YOUNG     MNICOLE     mnicole@zyx.com
# 9      31010            PAUL BREWER     PBREWER     pbrewer@zyx.com
# 10     31020       FRANCISCO MILLER     FMILLER     fmiller@zyx.com
# 11     31020       LESLIE HERNANDEZ  LHERNANDEZ  lhernandez@zyx.com
# 12     31020      KATHERINE SIMMONS    KSIMMONS    ksimmons@zyx.com
# 13     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 14     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 15     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 16     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 17     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 18     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 19     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 20     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 21     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 22     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 23     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 24     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 25     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 26     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 27     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 28     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# 29     31030          AMANDA WALLER     AWALLER     awaller@zyx.com
# ...      ...                    ...         ...                 ...
# 2551   7513A         KRISTA COLEMAN    KCOLEMAN    kcoleman@zyx.com
# 2552   7513A         KRISTA COLEMAN    KCOLEMAN    kcoleman@zyx.com
# 2553   7513A         KRISTA COLEMAN    KCOLEMAN    kcoleman@zyx.com
# 2554   75150        DOUGLAS ROBERTS    DROBERTS    droberts@zyx.com
# 2555   75150        DOUGLAS ROBERTS    DROBERTS    droberts@zyx.com
# 2556   75150        DOUGLAS ROBERTS    DROBERTS    droberts@zyx.com
# 2557   75150        DOUGLAS ROBERTS    DROBERTS    droberts@zyx.com
# 2558   7517J  MR. JACOB GONZALEZ MD      MJACOB      mjacob@zyx.com
# 2559   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2560   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2561   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2562   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2563   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2564   751AA           JULIE BUTLER     JBUTLER     jbutler@zyx.com
# 2565   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2566   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2567   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2568   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2569   751AA           JULIE BUTLER     JBUTLER     jbutler@zyx.com
# 2570   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2571   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2572   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2573   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2574   751AA           JULIE BUTLER     JBUTLER     jbutler@zyx.com
# 2575   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2576   751AA           JULIE BUTLER     JBUTLER     jbutler@zyx.com
# 2577   751AA        BRANDON GRIFFIN    BGRIFFIN    bgriffin@zyx.com
# 2578   751AA          BROOKE TAYLOR     BTAYLOR     btaylor@zyx.com
# 2579   77102       ANTHONY ROBINSON   AROBINSON   arobinson@zyx.com
# 2580   77105         JOEL HERNANDEZ  JHERNANDEZ  jhernandez@zyx.com
#
#                           ROLE_NAME                   OBJ_NAME  \
# 0               CONTRACTING OFFICER                   Contract
# 1                   NO LOGIN RIGHTS                   Contract
# 2                   NO LOGIN RIGHTS                   Contract
# 3                   NO LOGIN RIGHTS                   Contract
# 4                        ACCEPTANCE                   Contract
# 5                  SG_GENERAL ADMIN                   Contract
# 6                   NO LOGIN RIGHTS                   Contract
# 7                   NO LOGIN RIGHTS                   Contract
# 8                   NO LOGIN RIGHTS                   Contract
# 9                   NO LOGIN RIGHTS                   Contract
# 10                  NO LOGIN RIGHTS                   Contract
# 11                  NO LOGIN RIGHTS                   Contract
# 12                  NO LOGIN RIGHTS                   Contract
# 13              User Administration         AGREEMENTS OFFICER
# 14              User Administration              REQUISITIONER
# 15              User Administration     SG_CONTRACT SPECIALIST
# 16              User Administration                    TRAINEE
# 17              User Administration        SG_TSA-TEAM LEADERS
# 18              User Administration     SG_CONTRACTING OFFICER
# 19              User Administration              SG_SITE ADMIN
# 20              User Administration           SG_GENERAL ADMIN
# 21              User Administration           GRANT NEGOTIATOR
# 22              User Administration           CAN ASSIGN BUYER
# 23              User Administration                 ACCEPTANCE
# 24              User Administration  DISPLAY ALL ACCOUNT CODES
# 25              User Administration                  RECEIVING
# 26              User Administration           ORDERING OFFICER
# 27              User Administration            NO LOGIN RIGHTS
# 28              User Administration                 ACCOUNTING
# 29              User Administration         ABILITY TO RELEASE
# ...                             ...                        ...
# 2551      DISPLAY ALL ACCOUNT CODES                   Contract
# 2552  DISPLAY ALL AUTO-NUMBER MASKS                   Contract
# 2553         SG_CONTRACTING OFFICER                   Contract
# 2554             ABILITY TO RELEASE                   Contract
# 2555                          BUYER                   Contract
# 2556               CAN ASSIGN BUYER                   Contract
# 2557      DISPLAY ALL ACCOUNT CODES                   Contract
# 2558                NO LOGIN RIGHTS                   Contract
# 2559             ABILITY TO RELEASE                   Contract
# 2560             ABILITY TO RELEASE                   Contract
# 2561                     ACCOUNTING                   Contract
# 2562                          BUYER                   Contract
# 2563                          BUYER                   Contract
# 2564                          BUYER                   Contract
# 2565               CAN ASSIGN BUYER                   Contract
# 2566               CAN ASSIGN BUYER                   Contract
# 2567            CONTRACTING OFFICER                   Contract
# 2568            CONTRACTING OFFICER                   Contract
# 2569      DISPLAY ALL ACCOUNT CODES                   Contract
# 2570      DISPLAY ALL ACCOUNT CODES                   Contract
# 2571      DISPLAY ALL ACCOUNT CODES                   Contract
# 2572  DISPLAY ALL AUTO-NUMBER MASKS                   Contract
# 2573  DISPLAY ALL AUTO-NUMBER MASKS                   Contract
# 2574  DISPLAY ALL AUTO-NUMBER MASKS                   Contract
# 2575         SG_CONTRACT SPECIALIST                   Contract
# 2576         SG_CONTRACT SPECIALIST                   Contract
# 2577         SG_CONTRACTING OFFICER                   Contract
# 2578         SG_CONTRACTING OFFICER                   Contract
# 2579                NO LOGIN RIGHTS                   Contract
# 2580                NO LOGIN RIGHTS                   Contract
#
#                             FUNCTION_NAME STATUS
# 0     View                                     A
# 1     View                                     A
# 2     View                                     A
# 3     View                                     A
# 4     View                                     A
# 5     View                                     A
# 6     View                                     A
# 7     View                                     A
# 8     View                                     A
# 9     View                                     A
# 10    View                                     A
# 11    View                                     A
# 12    View                                     A
# 13    Assign                                   A
# 14    Assign                                   A
# 15    Assign                                   A
# 16    Assign                                   A
# 17    Assign                                   A
# 18    Assign                                   A
# 19    Assign                                   A
# 20    Assign                                   A
# 21    Assign                                   A
# 22    Assign                                   A
# 23    Assign                                   A
# 24    Assign                                   A
# 25    Assign                                   A
# 26    Assign                                   A
# 27    Assign                                   A
# 28    Assign                                   A
# 29    Assign                                   A
# ...                                   ...    ...
# 2551  View                                     A
# 2552  View                                     A
# 2553  View                                     A
# 2554  View                                     A
# 2555  View                                     A
# 2556  View                                     A
# 2557  View                                     A
# 2558  View                                     A
# 2559  View                                     A
# 2560  View                                     A
# 2561  View                                     A
# 2562  View                                     A
# 2563  View                                     A
# 2564  View                                     A
# 2565  View                                     A
# 2566  View                                     A
# 2567  View                                     A
# 2568  View                                     A
# 2569  View                                     A
# 2570  View                                     A
# 2571  View                                     A
# 2572  View                                     A
# 2573  View                                     A
# 2574  View                                     A
# 2575  View                                     A
# 2576  View                                     A
# 2577  View                                     A
# 2578  View                                     A
# 2579  View                                     A
# 2580  View                                     A
#
# [2581 rows x 8 columns]

# %%
term_path = 'files/term_employees_v1.xlsx'

# %%
term_df = pd.read_excel(term_path)

# %%
term_df
# Out:
#   Terminated Employees
# 0              MMEDINA
# 1            BGARRISON
# 2              KROGERS
# 3              MNEWMAN
# 4               EDAVIS
# 5             SSCHMIDT
# 6              DFLORES
# 7              JDALTON
# 8            JCAMPBELL
# 9               EHODGE

# %%
users_test = users_df[users_df['USER_ID'].isin(term_df['Terminated Employees'])]

# %%
users_test['TEST'] = users_test['STATUS'].map(lambda x: {'T': True, 'A': False}.get(x))

# %%
results = users_test[['USER_ID', 'STATUS', 'TEST']].groupby(['USER_ID', 'STATUS', 'TEST']).count().reset_index()

# %%
def summarize_results(results):
    number_of_terms = len(results)
    true_results = len(results[results['TEST']])
    false_results = len(results[~results['TEST']])
    print('----------------------RESULTS---------------------')
    print(f' There were {number_of_terms} terminations.')
    print(f' There were {true_results} users correctly shown as terminated.')
    if false_results:
        if false_results == 1:
            print(f' There was {false_results} user incorrectly shown as active.')
        else:
            print(f' There were {false_results} users incorrectly shown as active.')
    print('-'*50)

# %%
results
# Out:
#      USER_ID STATUS   TEST
# 0  BGARRISON      T   True
# 1    DFLORES      T   True
# 2     EDAVIS      T   True
# 3     EHODGE      A  False
# 4  JCAMPBELL      T   True
# 5    JDALTON      T   True
# 6    KROGERS      T   True
# 7    MMEDINA      T   True
# 8    MNEWMAN      T   True
# 9   SSCHMIDT      T   True

# %%
summarize_results(results)
# Out:
# ----------------------RESULTS---------------------
#  There were 10 terminations.
#  There were 9 users correctly shown as terminated.
#  There was 1 user incorrectly shown as active.
# --------------------------------------------------

# %% [markdown]
# # Conclusion
# Controls are not operating effectively for termination flags.

# %%
# !jupyter nbconvert --to html "full example.ipynb"
# Out:
# [NbConvertApp] Converting notebook full example.ipynb to html
# [NbConvertApp] Writing 280495 bytes to full example.html
